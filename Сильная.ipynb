# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sklearn.datasets import make_blobs
mpl.rcParams['figure.dpi'] = 300

# %%
# сильная корреляция
data_columns = ['column1', 'column2']
# rng = np.random.default_rng(12345)
# column_a = list(rng.integers(low=0, high=100, size=100))
# column_b = []
# for i in range(len(column_a)):
#     if i % 3 == 0:
#         column_b.append(column_a[i] + np.random.randint(low=5, high=10))
#     else:
#         column_b.append(np.random.randint(low=20, high=80))
column_a = [10, 15, 17, 23, 26, 27, 31, 35, 37, 42, 47, 54, 60, 65, 67, 70, 77, 89, 97, 100]
column_b = [9, 1, 10, 18, 15, 25, 30, 31, 34, 46, 30, 15, 25, 63, 63, 75, 43, 90, 93, 87]
result = zip(column_a, column_b)
data = pd.DataFrame(result, columns=data_columns)
data
# Out:
#     column1  column2
# 0        10        9
# 1        15        1
# 2        17       10
# 3        23       18
# 4        26       15
# 5        27       25
# 6        31       30
# 7        35       31
# 8        37       34
# 9        42       46
# 10       47       30
# 11       54       15
# 12       60       25
# 13       65       63
# 14       67       63
# 15       70       75
# 16       77       43
# 17       89       90
# 18       97       93
# 19      100       87

# %%
data.corr()
# Out:
#          column1  column2
# column1  1.00000  0.89732
# column2  0.89732  1.00000

# %%
scatter_kws = {'s': 20}
line_kws = {'color': 'red', 'lw': 1}
sns.regplot(data=data, x='column1', y='column2', scatter_kws=scatter_kws, line_kws=line_kws)
plt.show()
